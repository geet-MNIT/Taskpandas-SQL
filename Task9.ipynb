# %%
Superstore_USA
1 . load this data in sql and in pandas with a relation in sql 
2 . while loading this data you dont have to create a table manually you can use any automated approach to create a table and load a data in bulk in table 
3 . Find out how return that we ahve recived and with a product id 
4 . try  to join order and return data both in sql and pandas 
5 . Try to find out how many unique customer that we have 
6 . try to find out in how many regions we are selling a product and who is a manager for a respective region ###doubt
7 . #### doubt find out how many different differnet shipement mode that we have and what is a percentage usablity of all the shipment mode with respect to dataset 
8 . Create a new coulmn and try to find our a diffrence between order date and shipment date
9 . ###doubt base on question number 8 find out for which order id we have shipment duration more than 10 days 
10 . Try to find out a list of a returned order which sihpment duration was more then 15 days and find out that region manager as well 
11 . Gorup by region and find out which region is more profitable 
12 . Try to find out overalll in which country we are giving more didscount 
13 . Give me a list of unique postal code 
14 . which customer segement is more profitalble find it out . 
15 . try to find out the 10th most loss making product catagory . 
16 . Try to find out 10 top  product with highest margins

# %%
import pandas as pd

# %%
df1=pd.read_excel("Downloads/Superstore_USA.xlsx")

# %%
df1
# Out:
#       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0      18606  Not Specified      0.01        2.88           0.50            2
# 1      20847           High      0.01        2.84           0.93            3
# 2      23086  Not Specified      0.03        6.68           6.15            3
# 3      23087  Not Specified      0.01        5.68           3.60            3
# 4      23088  Not Specified      0.00      205.99           2.50            3
# ...      ...            ...       ...         ...            ...          ...
# 9421   20275       Critical      0.06       35.89          14.72         3402
# 9422   20276       Critical      0.00        3.34           7.49         3402
# 9423   24491  Not Specified      0.08      550.98          45.70         3402
# 9424   25914           High      0.10      105.98          13.99         3403
# 9425   24492  Not Specified      0.09        7.78           2.50         3403
#
# ...

# %%
df1.to_csv("Superstore_USA.csv", index=False)

# %%
df1
# Out:
#       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0      18606  Not Specified      0.01        2.88           0.50            2
# 1      20847           High      0.01        2.84           0.93            3
# 2      23086  Not Specified      0.03        6.68           6.15            3
# 3      23087  Not Specified      0.01        5.68           3.60            3
# 4      23088  Not Specified      0.00      205.99           2.50            3
# ...      ...            ...       ...         ...            ...          ...
# 9421   20275       Critical      0.06       35.89          14.72         3402
# 9422   20276       Critical      0.00        3.34           7.49         3402
# 9423   24491  Not Specified      0.08      550.98          45.70         3402
# 9424   25914           High      0.10      105.98          13.99         3403
# 9425   24492  Not Specified      0.09        7.78           2.50         3403
#
# ...

# %%
df2=pd.read_excel("Downloads/Superstore_USA.xlsx", sheet_name="Returns")

# %%
df2.to_csv("Superstore_USA_returns.csv", index=False)

# %%
df2
# Out:
#       Order ID    Status
# 0           65  Returned
# 1          612  Returned
# 2          614  Returned
# 3          678  Returned
# 4          710  Returned
# ...        ...       ...
# 1629    182681  Returned
# 1630    182683  Returned
# 1631    182750  Returned
# 1632    182781  Returned
# 1633    182906  Returned
#
# [1634 rows x 2 columns]

# %%
##3 . Find out how return that we ahve recived and with a product id 
pd.merge(df1,df2, on=["Order ID"], how="inner")[["Row ID", "Order ID", "Status"]]
# Out:
#     Row ID  Order ID    Status
# 0     1359      9895  Returned
# 1     1950     13959  Returned
# 2     1951     13959  Returned
# 3     5055     36038  Returned
# 4     5573     39490  Returned
# ..     ...       ...       ...
# 93     986      7107  Returned
# 94     987      7107  Returned
# 95    6041     42823  Returned
# 96    1910     13638  Returned
# 97    6625     47109  Returned
#
# [98 rows x 3 columns]

# %%
##5 . Try to find out how many unique customer that we have 
df1.groupby("Customer Name")["Customer Name"].unique().count()
# Out:
# 2703

# %%
df1["Customer Name"].value_counts()
# Out:
# Louis Parrish            27
# Jenny Gold               26
# Leigh Burnette Hurley    22
# Sean N Boyer             22
# Andrew Gonzalez          21
#                          ..
# Kent Hoover               1
# Ruby Booth                1
# Bill Hudson               1
# Angela Wooten             1
# Janice Fletcher           1
# Name: Customer Name, Length: 2703, dtype: int64

# %%
###6 .try to find out in how many regions we are selling a product and who is a manager for a respective region 
df3=pd.read_excel("Downloads/Superstore_USA.xlsx", sheet_name="Users")

# %%
df3.to_csv("Superstore_USA_Users.csv", index=False)

# %%
df1.groupby(["Region"])["Region"].unique().count()
# Out:
# 4

# %%
df3.groupby(["Region","Manager"]).count()
# Out:
# Empty DataFrame
# Columns: []
# Index: [(Central, Chris), (East, Erin), (South, Sam), (West, William)]

# %%
###7 . find out how many different differnet shipement mode that we have and what is a percentage usablity of all the shipment mode with respect to dataset
df1.groupby(["Ship Mode"])["Shipping Cost"].sum().groupby(level = 0).transform(lambda x: x/x.sum())
# Out:
# Ship Mode
# Delivery Truck    1.0
# Express Air       1.0
# Regular Air       1.0
# Name: Shipping Cost, dtype: float64

# %%
###8 . Create a new coulmn and try to find our a diffrence between order date and shipment date
df1["difference"]=(df1["Ship Date"]-df1["Order Date"]).dt.days

# %%
df1.head(20)
# Out:
#     Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0    18606  Not Specified      0.01        2.88           0.50            2
# 1    20847           High      0.01        2.84           0.93            3
# 2    23086  Not Specified      0.03        6.68           6.15            3
# 3    23087  Not Specified      0.01        5.68           3.60            3
# 4    23088  Not Specified      0.00      205.99           2.50            3
# 5    23597         Medium      0.09       55.48          14.30            3
# 6    25549            Low      0.08      120.97          26.30            3
# 7    20228  Not Specified      0.02      500.98          26.00            5
# 8    19483            Low      0.08        6.48           6.81            5
# 9    24782           High      0.01       90.24           0.99            6
# 10   24563       Critical      0.07        6.48           6.60            6
# ...

# %%
##9 . base on question number 8 find out for which order id we have shipment duration more than 10 days 
df1[df1["difference"] > 10][["Order ID", "difference"]]
# Out:
#       Order ID  difference
# 643      87215          84
# 1548     86318          11
# 1549     86318          15
# 1678     87957          17
# 1679     87957          11
# 1680     87957          28
# 1697     19556          17
# 1698     19556          11
# 1699     19556          28
# 2515     86177          92
# 5548     88223          14
# 5673     88352          17
# 5859     87572          22
# 5881     91294          24
# 8607     86434          18
# 8609     86436          17
# 8610     86436          19
# 8973     87300          19
# 8982     19841          27
# 8983     19841          31
# 8993     19841          19
# 8996     87300          27
# 8997     87300          31

# %%
gt=df1[df1["difference"] > 5][["Order ID", "difference", "Region"]]

# %%
gt
# Out:
#       Order ID  difference   Region
# 6        88526           7     West
# 8        90197           9     West
# 60       87669           7     West
# 88       89203           7     West
# 109      91456           6     West
# ...        ...         ...      ...
# 9307     90510           7     East
# 9346     88841           7    South
# 9370     88752           7     East
# 9389     87910           7     West
# 9397     87548           7  Central
#
# [517 rows x 3 columns]

# %%
##10 . Try to find out a list of a returned order which sihpment duration was more then 15 days and find out that region manager as well
#pd.merge(df1[df1["difference"] > 15], df2, on=)
df4=pd.merge(gt,df2, on="Order ID", how="inner")[["Order ID", "Status", "difference", "Region"]]

# %%
df4
# Out:
#    Order ID    Status  difference Region
# 0     51559  Returned           9   West
# 1     41760  Returned           7   East
# 2     32931  Returned           7   West

# %%
df5=pd.merge(df3,df4, on="Region")[["Status","difference", "Manager"]]

# %%
df5
# Out:
#      Status  difference  Manager
# 0  Returned           7     Erin
# 1  Returned           9  William
# 2  Returned           7  William

# %%
df5[df5["difference"]>15]   ### output is null if >15 is used
# Out:
# Empty DataFrame
# Columns: [Status, difference, Manager]
# Index: []

# %%
##11 . Group by region and find out which region is more profitable
df1.groupby(["Region"])["Profit"].sum()
# Out:
# Region
# Central    519825.567067
# East       377566.186045
# South      104201.192420
# West       310849.453897
# Name: Profit, dtype: float64

# %%
df1.groupby(["Region"])["Profit"].sum().max()
# Out:
# 519825.56706659996

# %%
##12 . Try to find out overall in which country we are giving more discount 
df1.groupby(["State or Province"])[["Discount"]].sum()
# Out:
#                       Discount
# State or Province
# Alabama                   5.87
# Arizona                   6.86
# Arkansas                  5.80
# California               52.28
# Colorado                  8.05
# Connecticut               4.28
# Delaware                  0.66
# District of Columbia      3.10
# Florida                  26.38
# Georgia                   9.79
# Idaho                     5.57
# Illinois                 29.71
# Indiana                  12.22
# Iowa                      7.15
# Kansas                    6.89
# Kentucky                  4.23
# Louisiana                 4.86
# Maine                     6.66
# Maryland                  8.85
# Massachusetts            11.22
# Michigan                 15.29
# Minnesota                12.52
# Mississippi               3.89
# Missouri                  8.09
# Montana                   2.39
# Nebraska                  3.59
# Nevada                    1.80
# New Hampshire             2.62
# ...

# %%
df1.groupby(["State or Province"])[["Discount","State or Province"]].sum().max()
# Out:
# Discount    52.28
# dtype: float64

# %%
##13 . Give me a list of unique postal code 
df1["Postal Code"].unique()
# Out:
# array([60101, 98221, 91776, ..., 61832, 62521, 26554], dtype=int64)

# %%
##14 . which customer segement is more profitalble find it out .
df1.groupby("Customer Segment")["Profit"].sum()
# Out:
# Customer Segment
# Consumer          206559.625348
# Corporate         505538.627783
# Home Office       283869.553814
# Small Business    316474.592482
# Name: Profit, dtype: float64

# %%
df1.groupby("Customer Segment")["Profit"].sum().max()
# Out:
# 505538.62778304

# %%
##15 . try to find out the 10th most loss making product catagory.
df1.groupby(["Product Category"])["Profit"].sum().iloc[0:1]
# Out:
# Product Category
# Furniture    177354.298188
# Name: Profit, dtype: float64

# %%
##16 .Try to find out 10 top product with highest margins 
df1.groupby("Product Name")["Product Base Margin"].sum().nlargest(10)
# Out:
# Product Name
# Global High-Back Leather Tilter, Burgundy                                                    19.98
# BoxOffice By Design Rectangular and Half-Moon Meeting Room Tables                            18.33
# Bevis 36 x 72 Conference Tables                                                              16.38
# Adesso Programmable 142-Key Keyboard                                                         15.45
# Accessory36                                                                                  14.11
# Office Star - Mid Back Dual function Ergonomic High Back Chair with 2-Way Adjustable Arms    13.64
# Office Star - Contemporary Task Swivel chair with 2-way adjustable arms, Plum                13.26
# Microsoft Internet Keyboard                                                                  13.21
# StarTAC 7760                                                                                 12.98
# ...

# %%
####Mysql
import mysql.connector as conn

# %%
df1.to_csv("Superstore_USA.csv", sep='@', index=False)

# %%
mydb=conn.connect(host="localhost", user="root", passwd="mysql")
cursor=mydb.cursor()
query1="create database if not exists tasksql"
cursor.execute(query1)

# %%
query2="create table if not exists tasksql.table2(RowID int, OrderPriority varchar(20), Discount decimal(15,3), UnitPrice decimal(10), ShippingCost decimal(10), CustomerID int, CustomerName varchar(40), ShipMode varchar(20), CustomerSegment varchar(20), ProductCategory varchar(20), ProductSubCategory varchar(30), ProductContainer varchar(20), ProductName varchar(100), ProductBaseMargin decimal(10), Region varchar(15), StateorProvince varchar(20), City varchar(20), PostalCode int, OrderDate datetime, ShipDate datetime, Profit decimal(20), Quantityorderednew int, Sales decimal(20), OrderID int)"
cursor.execute(query2)

# %%
import csv

# %%
mydb = conn.connect(host="localhost",user="root", passwd="mysql",use_pure=True)
cursor = mydb.cursor()
with open('Superstore_USA.csv',encoding="utf8") as data:
    next(data)
    data_csv=csv.reader(data, delimiter="\n")
    print(data_csv)
    for i in data_csv:
        cursor.execute('insert into tasksql.table2 values ({})'.format(",".join(['"' + k + '"' for k in i[0].split("@")])))
        #cursor.execute('insert into sqlassign.AttributeDataSet values ({data})'.format(data=(i[0])))
        #print((str(i)))
        print("all the data inserted")
mydb.commit()
# Out:
# ...
# all the data inserted
# all the data inserted
# all the data inserted
# all the data inserted
# all the data inserted
# all the data inserted
# all the data inserted
# all the data inserted
# all the data inserted
# all the data inserted
# all the data inserted
# all the data inserted
# all the data inserted
# all the data inserted
# all the data inserted
# all the data inserted
# all the data inserted
# all the data inserted
# all the data inserted
# all the data inserted
# all the data inserted
# all the data inserted
# all the data inserted
# all the data inserted
# all the data inserted
# all the data inserted
# all the data inserted
# all the data inserted
# all the data inserted
# all the data inserted
# all the data inserted
# all the data inserted
# all the data inserted
# all the data inserted
# all the data inserted
# all the data inserted
# all the data inserted
# all the data inserted
# all the data inserted
# all the data inserted
# all the data inserted
# ...

# %%
mydb = conn.connect(host="localhost",user="root", database="tasksql", passwd="mysql",use_pure=True)
cursor = mydb.cursor()
query3="create table if not exists tasksql.table3(OrderID int, Status varchar(10))"
cursor.execute(query3)

# %%
mydb = conn.connect(host="localhost",user="root", passwd="mysql",use_pure=True)
cursor = mydb.cursor()
with open('Superstore_USA_returns.csv',encoding="utf8") as data:
    next(data)
    data_csv=csv.reader(data, delimiter="\n")
    print(data_csv)
    for i in data_csv:
        cursor.execute('insert into tasksql.table3 values ({})'.format(",".join(['"' + k + '"' for k in i[0].split(",")])))
        #cursor.execute('insert into sqlassign.AttributeDataSet values ({data})'.format(data=(i[0])))
        #print((str(i)))
        print("all the data inserted")
mydb.commit()
# Out:
# ...
# all the data inserted
# all the data inserted
# all the data inserted
# all the data inserted
# all the data inserted
# all the data inserted
# all the data inserted
# all the data inserted
# all the data inserted
# all the data inserted
# all the data inserted
# all the data inserted
# all the data inserted
# all the data inserted
# all the data inserted
# all the data inserted
# all the data inserted
# all the data inserted
# all the data inserted
# all the data inserted
# all the data inserted
# all the data inserted
# all the data inserted
# all the data inserted
# all the data inserted
# all the data inserted
# all the data inserted
# all the data inserted
# all the data inserted
# all the data inserted
# all the data inserted
# all the data inserted
# all the data inserted
# all the data inserted
# all the data inserted
# all the data inserted
# all the data inserted
# all the data inserted
# all the data inserted
# all the data inserted
# all the data inserted
# ...

# %%
mydb = conn.connect(host="localhost",user="root", database="tasksql", passwd="mysql",use_pure=True)
cursor = mydb.cursor()
query3="create table if not exists tasksql.table4(Region varchar(10), Manager varchar(10))"
cursor.execute(query3)

# %%
mydb = conn.connect(host="localhost",user="root", passwd="mysql",use_pure=True)
cursor = mydb.cursor()
with open('Superstore_USA_Users.csv',encoding="utf8") as data:
    next(data)
    data_csv=csv.reader(data, delimiter="\n")
    print(data_csv)
    for i in data_csv:
        cursor.execute('insert into tasksql.table4 values ({})'.format(",".join(['"' + k + '"' for k in i[0].split(",")])))
        #cursor.execute('insert into sqlassign.AttributeDataSet values ({data})'.format(data=(i[0])))
        #print((str(i)))
        print("all the data inserted")
mydb.commit()
# Out:
# ...
# all the data inserted
# all the data inserted
# all the data inserted
# all the data inserted

# %%
###3 . Find out how return that we have recived and with a product id 
mydb = conn.connect(host="localhost",user="root", database="tasksql", passwd="mysql",use_pure=True)
cursor = mydb.cursor()
query4="select count(RowID) from (select table2.RowID, table3.Status from table2 inner join table3 on table2.OrderID=table3.OrderID) table2;"
cursor.execute(query4)
for i in cursor.fetchall():
    print(i)
# Out:
# (98,)

# %%
##5 .Try to find out how many unique customer that we have 
mydb = conn.connect(host="localhost",user="root", database="tasksql", passwd="mysql",use_pure=True)
cursor = mydb.cursor()
query5="select count(distinct CustomerName) from table2;"
cursor.execute(query5)
for i in cursor.fetchall():
    print(i)
# Out:
# (2703,)

# %%
###6 .try to find out in how many regions we are selling a product and who is a manager for a respective region ###doubt
mydb = conn.connect(host="localhost",user="root", database="tasksql", passwd="mysql",use_pure=True)
cursor = mydb.cursor()
query6="select count(distinct table2.Region), table2.Region, table4.Manager from table2 inner join table4  on table2.Region=table4.region group by table2.Region;"
query7="select count(distinct Region) from table2;"
cursor.execute(query6)
for i in cursor.fetchall():
    print(i)
cursor.execute(query7)
for i in cursor.fetchall():
    print(i)
# Out:
# (1, 'Central', 'Chris')
# (1, 'East', 'Erin')
# (1, 'South', 'Sam')
# (1, 'West', 'William')
# (4,)

# %%
###7 . find out how many different differnet shipement mode that we have and what is a percentage usablity of all the shipment mode with respect to dataset

# %%
###8. Create a new coulmn and try to find our a diffrence between order date and shipment date
mydb = conn.connect(host="localhost",user="root", database="tasksql", passwd="mysql",use_pure=True)
cursor = mydb.cursor()
#query8="alter table table2 add difference datetime;"
query9="select table2.ShipDate, table2.OrderDate, ShipDate-OrderDate as difference from table2;"
cursor.execute(query9)
for i in cursor.fetchall():
    print(i)
# Out:
# (datetime.datetime(2012, 5, 30, 0, 0), datetime.datetime(2012, 5, 28, 0, 0), 2000000)
# (datetime.datetime(2010, 7, 8, 0, 0), datetime.datetime(2010, 7, 7, 0, 0), 1000000)
# (datetime.datetime(2011, 7, 28, 0, 0), datetime.datetime(2011, 7, 27, 0, 0), 1000000)
# (datetime.datetime(2011, 7, 28, 0, 0), datetime.datetime(2011, 7, 27, 0, 0), 1000000)
# (datetime.datetime(2011, 7, 27, 0, 0), datetime.datetime(2011, 7, 27, 0, 0), 0)
# (datetime.datetime(2011, 11, 11, 0, 0), datetime.datetime(2011, 11, 9, 0, 0), 2000000)
# (datetime.datetime(2013, 7, 8, 0, 0), datetime.datetime(2013, 7, 1, 0, 0), 7000000)
# (datetime.datetime(2010, 12, 15, 0, 0), datetime.datetime(2010, 12, 13, 0, 0), 2000000)
# (datetime.datetime(2012, 5, 21, 0, 0), datetime.datetime(2012, 5, 12, 0, 0), 9000000)
# (datetime.datetime(2011, 5, 26, 0, 0), datetime.datetime(2011, 5, 26, 0, 0), 0)
# (datetime.datetime(2012, 12, 31, 0, 0), datetime.datetime(2012, 12, 29, 0, 0), 2000000)
# ...

# %%
###9 . based on question number 8 find out for which order id we have shipment duration more than 10 days 
mydb = conn.connect(host="localhost",user="root", database="tasksql", passwd="mysql",use_pure=True)
cursor = mydb.cursor()
#query8="alter table table2 add difference datetime;"
query10="select OrderID, difference from table2 where difference >10;"
cursor.execute(query10)
for i in cursor.fetchall():
    print(i)

# %%
###10 . Try to find out a list of a returned order which sihpment duration was more then 15 days and find out that region manager as well

# %%
###11 . Gorup by region and find out which region is more profitable 
mydb = conn.connect(host="localhost",user="root", database="tasksql", passwd="mysql",use_pure=True)
cursor = mydb.cursor()
query11="select Region, sum(Profit) from table2 group by Region order by sum(Profit) desc limit 1;"
cursor.execute(query11)
for i in cursor.fetchall():
    print(i)
# Out:
# ('Central', Decimal('519829'))

# %%
##12 .Try to find out overalll in which country we are giving more discount 
mydb = conn.connect(host="localhost",user="root", database="tasksql", passwd="mysql",use_pure=True)
cursor = mydb.cursor()
query12="select StateorProvince, sum(discount) from table2 group by StateorProvince order by sum(discount) desc limit 1;"
cursor.execute(query12)
for i in cursor.fetchall():
    print(i)
# Out:
# ('California', Decimal('52.280'))

# %%
##13 . Give me a list of unique postal code 
mydb = conn.connect(host="localhost",user="root", database="tasksql", passwd="mysql",use_pure=True)
cursor = mydb.cursor()
query12="select distinct PostalCode from table2;"
cursor.execute(query12)
for i in cursor.fetchall():
    print(i)
# Out:
# (60101,)
# (98221,)
# (91776,)
# (95123,)
# (2724,)
# (3110,)
# (8101,)
# (8109,)
# (7203,)
# (2907,)
# (55372,)
# (11787,)
# (13210,)
# (59405,)
# (59601,)
# (59801,)
# (68005,)
# (10012,)
# (92653,)
# (92677,)
# (92530,)
# (92630,)
# (90712,)
# (93534,)
# (90260,)
# (97405,)
# (97526,)
# (97030,)
# (97123,)
# (97303,)
# (62002,)
# (98373,)
# (98052,)
# (75019,)
# (23834,)
# (62701,)
# (60107,)
# (60477,)
# (14150,)
# (12180,)
# (77642,)
# (75080,)
# (77471,)
# (78664,)
# (75088,)
# (24153,)
# (94043,)
# (92563,)
# (94559,)
# (10177,)
# (2917,)
# (5401,)
# (4070,)
# (2331,)
# (8830,)
# (8701,)
# (7470,)
# (7481,)
# (5201,)
# (97035,)
# (44708,)
# (45231,)
# (44105,)
# (95687,)
# (5451,)
# (94591,)
# (70056,)
# (22102,)
# (60601,)
# (66209,)
# (66215,)
# (66502,)
# (66062,)
# (6510,)
# (4401,)
# (4005,)
# (2129,)
# (2038,)
# (1852,)
# (1752,)
# (2067,)
# (3820,)
# (8618,)
# (7644,)
# (7110,)
# (8861,)
# (7095,)
# (2895,)
# (97128,)
# (97504,)
# (98103,)
# (84118,)
# (84041,)
# ...

# %%
###14. which customer segement is more profitalble find it out. 
mydb = conn.connect(host="localhost",user="root", database="tasksql", passwd="mysql",use_pure=True)
cursor = mydb.cursor()
query13="select CustomerSegment, sum(Profit) from table2 group by CustomerSegment order by sum(Profit) desc limit 1"
cursor.execute(query13)
for i in cursor.fetchall():
    print(i)
# Out:
# ('Corporate', Decimal('505515'))

# %%
##15 . try to find out the 10th most loss making product catagory . 
mydb = conn.connect(host="localhost",user="root", database="tasksql", passwd="mysql",use_pure=True)
cursor = mydb.cursor()
query14="select ProductCategory, sum(Profit) from table2 group by ProductCategory order by sum(Profit);"
cursor.execute(query14)
for i in cursor.fetchall():
    print(i)
# Out:
# ('Furniture', Decimal('177337'))
# ('Office Supplies', Decimal('451990'))
# ('Technology', Decimal('683088'))

# %%
###16 . Try to find out 10 top product with highest margins 
mydb = conn.connect(host="localhost",user="root", database="tasksql", passwd="mysql",use_pure=True)
cursor = mydb.cursor()
query15="select ProductName, sum(ProductBaseMargin) from table2 group by ProductName order by sum(ProductBaseMargin) desc limit 10;"
cursor.execute(query15)
for i in cursor.fetchall():
    print(i)
# Out:
# ('Global High-Back Leather Tilter, Burgundy', Decimal('27'))
# ('Bevis 36 x 72 Conference Tables', Decimal('26'))
# ('BoxOffice By Design Rectangular and Half-Moon Meeting Room Tables', Decimal('24'))
# ('Fiskars® Softgrip Scissors', Decimal('22'))
# ('StarTAC 7760', Decimal('22'))
# ('80 Minute CD-R Spindle, 100/Pack - Staples', Decimal('22'))
# ('Office Star - Mid Back Dual function Ergonomic High Back Chair with 2-Way Adjustable Arms', Decimal('22'))
# ('Bell Sonecor JB700 Caller ID', Decimal('21'))
# ('Global Troy™ Executive Leather Low-Back Tilter', Decimal('21'))
# ('Imation 3.5, DISKETTE 44766 HGHLD3.52HD/FM, 10/Pack', Decimal('21'))
